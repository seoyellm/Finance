# %% [markdown]
# # 실습_01

# %%
from pykrx import stock
from pykrx import bond
import FinanceDataReader as fdr

from IPython.display import Image
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns


import warnings
warnings.filterwarnings(action='ignore')

#-------------------- 차트 관련 속성 (한글처리, 그리드) -----------
sns.set()
#plt.rc('font', family='NanumGothicOTF') # For MacOS
plt.rcParams['font.family']= 'Malgun Gothic'
plt.rcParams['axes.unicode_minus'] = False


#-------------------- 주피터 , 출력결과 넓이 늘리기 ---------------
from IPython.core.display import display, HTML
display(HTML("<style>.container{width:100% !important;}</style>"))
pd.set_option('display.max_rows', 100)
pd.set_option('display.max_columns', 100)
pd.set_option('max_colwidth', None)
# Out:
# <style>.container{width:100% !important;}</style>

# %% [markdown]
# # 1. krx api 시총 top10 업종명, 업종코드

# %% [markdown]
# ## 내꺼

# %%
from pykrx import stock  # 주식  api
from pykrx import bond 

df = stock.get_market_cap("20230403")
code_list=df['시가총액'].sort_values(ascending=False)[:10].index

print(code_list)
# Out:
# Index(['005930', '373220', '000660', '207940', '006400', '051910', '005935',
#        '005380', '005490', '000270'],
#       dtype='object', name='티커')

# %%
df
# Out:
#             종가             시가총액       거래량          거래대금       상장주식수
# 티커
# 005930   63100  376693278905000  11973133  757289145500  5969782550
# 373220  586000  137124000000000    330892  193253021000   234000000
# 000660   87200   63481806228000   2502220  218381638252   728002365
# 207940  778000   55373372000000     59605   46677774000    71174000
# 006400  745000   51229574850000    222650  165048247000    68764530
# ...        ...              ...       ...           ...         ...
# 288490      48       1831056000     35714       1782290    38147000
# 267060     181       1654666524         0             0     9141804
# 267810     900       1608300000      8873       4676867     1787000
# 308700     329       1316000000        16          5127     4000000
# 322190     120       1071023640        46          5982     8925197
#
# [2712 rows x 5 columns]

# %%
top10_list=[]
for i in code_list:
    name = stock.get_market_ticker_name(i)
    top10_list.append(name)
print(top10_list)
# Out:
# ['삼성전자', 'LG에너지솔루션', 'SK하이닉스', '삼성바이오로직스', '삼성SDI', 'LG화학', '삼성전자우', '현대차', 'POSCO홀딩스', '기아']

# %% [markdown]
# ## 강사님

# %%
from pykrx import stock

# %%
mc_df = stock.get_market_cap("20230403")[:10]
print(mc_df)
# Out:
#             종가             시가총액       거래량           거래대금       상장주식수
# 티커
# 005930   63100  376693278905000  11973133   757289145500  5969782550
# 373220  586000  137124000000000    330892   193253021000   234000000
# 000660   87200   63481806228000   2502220   218381638252   728002365
# 207940  778000   55373372000000     59605    46677774000    71174000
# 006400  745000   51229574850000    222650   165048247000    68764530
# 051910  712000   50261748216000    210319   150842882268    70592343
# 005935   53800   44271304460000   1260998    67903365377   822886700
# 005380  183600   38837184501600    534323    98177726628   211531506
# 005490  392000   33151922160000   2647969  1039998810500    84571230
# 000270   81200   32915503776400    807758    65494082400   405363347

# %%
top10_idx_list   = mc_df.index
top10_idx_list
# Out:
# Index(['005930', '373220', '000660', '207940', '006400', '051910', '005935',
#        '005380', '005490', '000270'],
#       dtype='object', name='티커')

# %%
for ticker in top10_idx_list:
    티커명 = stock.get_market_ticker_name(ticker)
    print(ticker, 티커명)
# Out:
# 005930 삼성전자
# 373220 LG에너지솔루션
# 000660 SK하이닉스
# 207940 삼성바이오로직스
# 006400 삼성SDI
# 051910 LG화학
# 005935 삼성전자우
# 005380 현대차
# 005490 POSCO홀딩스
# 000270 기아

# %% [markdown]
# # 2. krx api 시총 top10 업종명, 업종코드, 종가 가져오기
# * 기준일자 : 20230403
# * krx API 이용
# * df = stock.get_market_cap("20200625")
# * df = stock.get_market_ohlcv("20220720", "20220810", "005930")

# %% [markdown]
# ## 내꺼

# %% [markdown]
# ### get_market_cap

# %%
df = stock.get_market_cap("20230403")[:10]

# %%
종가_list=df['종가'].values

# %%
dic={'티커':code_list,'티커명':top10_list,'종가':종가_list}

# %%
ticker_df=pd.DataFrame(dic)
ticker_df
# Out:
#        티커       티커명      종가
# 0  005930      삼성전자   63100
# 1  373220  LG에너지솔루션  586000
# 2  000660    SK하이닉스   87200
# 3  207940  삼성바이오로직스  778000
# 4  006400     삼성SDI  745000
# 5  051910      LG화학  712000
# 6  005935     삼성전자우   53800
# 7  005380       현대차  183600
# 8  005490  POSCO홀딩스  392000
# 9  000270        기아   81200

# %% [markdown]
# ### get_market_ohlcv

# %%
df = stock.get_market_ohlcv("20230403")
df.head()
# Out:
#             시가      고가      저가      종가     거래량        거래대금   등락률
# 티커
# 095570    4705    4750    4625    4650  191846   897688315 -1.27
# 006840   17890   18420   17560   18180   40650   732699210  1.68
# 027410    4355    4525    4260    4520  224171   995444345  4.27
# 282330  181800  183500  180400  180700   22103  4004331800 -0.55
# 138930    6520    6530    6440    6490  977713  6332241390 -0.31

# %%
close_list=df['종가'].loc[code_list].values
close_list
# Out:
# array([ 63100, 586000,  87200, 778000, 745000, 712000,  53800, 183600,
#        392000,  81200])

# %%
dic={'티커':code_list,'티커명':top10_list,'종가':close_list}
pd.DataFrame(dic)
# Out:
#        티커       티커명      종가
# 0  005930      삼성전자   63100
# 1  373220  LG에너지솔루션  586000
# 2  000660    SK하이닉스   87200
# 3  207940  삼성바이오로직스  778000
# 4  006400     삼성SDI  745000
# 5  051910      LG화학  712000
# 6  005935     삼성전자우   53800
# 7  005380       현대차  183600
# 8  005490  POSCO홀딩스  392000
# 9  000270        기아   81200

# %%
df = stock.get_market_ohlcv("20230403", "20230425",'005930')
df.head()
# Out:
#                시가     고가     저가     종가       거래량           거래대금   등락률
# 날짜
# 2023-04-03  64000  64000  63000  63100  11973133   757289145500 -1.41
# 2023-04-04  63400  63800  62800  63600  11120514   706088571400  0.79
# 2023-04-05  63700  64000  63400  63900   9176149   584822515500  0.47
# 2023-04-06  63500  63600  62300  62300  14992747   940919458200 -2.50
# 2023-04-07  63800  65200  63800  65000  27476120  1778208943700  4.33

# %%
a_list=[]
for i in range(len(code_list)):
    df = stock.get_market_ohlcv("20230403", "20230425",code_list[i])
    a_list.append([top10_list[i],df['종가'].values])

a=dict(a_list)
a_df=pd.DataFrame(a,index=df.index)
a_df
# Out:
#              삼성전자  LG에너지솔루션  SK하이닉스  삼성바이오로직스   삼성SDI    LG화학  삼성전자우     현대차  \
# 날짜
# 2023-04-03  63100    586000   87200    778000  745000  712000  53800  183600
# 2023-04-04  63600    575000   84500    788000  726000  722000  53700  183800
# 2023-04-05  63900    588000   84600    788000  778000  732000  53800  186700
# 2023-04-06  62300    580000   83800    805000  745000  716000  53100  185100
# 2023-04-07  65000    580000   89100    796000  738000  714000  54800  185100
# 2023-04-10  65700    596000   90700    803000  749000  750000  55800  185900
# 2023-04-11  65900    610000   91800    812000  767000  806000  55300  192100
# 2023-04-12  66000    590000   90300    800000  764000  775000  55600  198200
# 2023-04-13  66100    599000   88700    815000  769000  802000  55000  198900
# 2023-04-14  65100    594000   89300    817000  762000  802000  55200  196100
# 2023-04-17  65300    591000   88500    812000  755000  805000  55700  195000
# ...

# %% [markdown]
# ## 규환님

# %%
new_df=pd.DataFrame()

# %%
for ticker in code_list:
    종가 = stock.get_market_ohlcv("2023-04-03", "2023-04-24", ticker)['종가']
    종목명 = stock.get_market_ticker_name(ticker)
    new_df[종목명] = 종가
new_df
# Out:
#              삼성전자  LG에너지솔루션  SK하이닉스  삼성바이오로직스   삼성SDI    LG화학  삼성전자우     현대차  \
# 날짜
# 2023-04-03  63100    586000   87200    778000  745000  712000  53800  183600
# 2023-04-04  63600    575000   84500    788000  726000  722000  53700  183800
# 2023-04-05  63900    588000   84600    788000  778000  732000  53800  186700
# 2023-04-06  62300    580000   83800    805000  745000  716000  53100  185100
# 2023-04-07  65000    580000   89100    796000  738000  714000  54800  185100
# 2023-04-10  65700    596000   90700    803000  749000  750000  55800  185900
# 2023-04-11  65900    610000   91800    812000  767000  806000  55300  192100
# 2023-04-12  66000    590000   90300    800000  764000  775000  55600  198200
# 2023-04-13  66100    599000   88700    815000  769000  802000  55000  198900
# 2023-04-14  65100    594000   89300    817000  762000  802000  55200  196100
# 2023-04-17  65300    591000   88500    812000  755000  805000  55700  195000
# ...

# %% [markdown]
# ### 강사님

# %% [markdown]
# ## 방법1) 기준일자 : 20230403

# %%
df = stock.get_market_cap("20230403")[:10]
df = df[['종가']]
df = df.reset_index()

temp_list = []
for ticker in df['티커']:
    티커명 = stock.get_market_ticker_name(ticker)
    temp_list.append(티커명)
df['티커명'] = temp_list
df
# Out:
#        티커      종가       티커명
# 0  005930   63100      삼성전자
# 1  373220  586000  LG에너지솔루션
# 2  000660   87200    SK하이닉스
# 3  207940  778000  삼성바이오로직스
# 4  006400  745000     삼성SDI
# 5  051910  712000      LG화학
# 6  005935   53800     삼성전자우
# 7  005380  183600       현대차
# 8  005490  392000  POSCO홀딩스
# 9  000270   81200        기아

# %% [markdown]
# ## 방법2) 기준일자 : 20230403 ~ 20230425

# %%
# ohlcv_df = stock.get_market_ohlcv("20230403", "20230425", "005490")
# ohlcv_df = ohlcv_df.iloc[:, 3:4]
# ohlcv_df.columns = ['삼성']
# ohlcv_df

# %%
idx_list = stock.get_market_cap("20230403")[:10].index
ticker_name_list = []
for ticker in df['티커']:
    티커명 = stock.get_market_ticker_name(ticker)
    print(ticker, 티커명)
    ticker_name_list.append(티커명)
ticker_name_list
# Out:
# 005930 삼성전자
# 373220 LG에너지솔루션
# 000660 SK하이닉스
# 207940 삼성바이오로직스
# 006400 삼성SDI
# 051910 LG화학
# 005935 삼성전자우
# 005380 현대차
# 005490 POSCO홀딩스
# 000270 기아
# ['삼성전자',
#  'LG에너지솔루션',
#  'SK하이닉스',
#  '삼성바이오로직스',
#  '삼성SDI',
#  'LG화학',
#  '삼성전자우',
#  '현대차',
#  'POSCO홀딩스',
#  '기아']

# %%
df_list = []
for ticker in idx_list:
    ohlcv_df = stock.get_market_ohlcv("20230403", "20230425", ticker)
    ohlcv_df = ohlcv_df.iloc[:, 3:4]
    df_list.append(ohlcv_df)
    
tot_df = pd.concat(df_list, axis=1)
tot_df.columns = ticker_name_list  
tot_df
# Out:
#              삼성전자  LG에너지솔루션  SK하이닉스  삼성바이오로직스   삼성SDI    LG화학  삼성전자우     현대차  \
# 날짜
# 2023-04-03  63100    586000   87200    778000  745000  712000  53800  183600
# 2023-04-04  63600    575000   84500    788000  726000  722000  53700  183800
# 2023-04-05  63900    588000   84600    788000  778000  732000  53800  186700
# 2023-04-06  62300    580000   83800    805000  745000  716000  53100  185100
# 2023-04-07  65000    580000   89100    796000  738000  714000  54800  185100
# 2023-04-10  65700    596000   90700    803000  749000  750000  55800  185900
# 2023-04-11  65900    610000   91800    812000  767000  806000  55300  192100
# 2023-04-12  66000    590000   90300    800000  764000  775000  55600  198200
# 2023-04-13  66100    599000   88700    815000  769000  802000  55000  198900
# 2023-04-14  65100    594000   89300    817000  762000  802000  55200  196100
# 2023-04-17  65300    591000   88500    812000  755000  805000  55700  195000
# ...

# %%
tot_df.to_csv('../datasets/kospi_top10.csv')

# %% [markdown]
# # 상위 종목 지수화
# - 수익률
# - ret_df

# %% [markdown]
# ## 내꺼

# %%
ret_df=new_df.pct_change(1)
ret_df
# Out:
#                 삼성전자  LG에너지솔루션    SK하이닉스  삼성바이오로직스     삼성SDI      LG화학  \
# 날짜
# 2023-04-03       NaN       NaN       NaN       NaN       NaN       NaN
# 2023-04-04  0.007924 -0.018771 -0.030963  0.012853 -0.025503  0.014045
# 2023-04-05  0.004717  0.022609  0.001183  0.000000  0.071625  0.013850
# 2023-04-06 -0.025039 -0.013605 -0.009456  0.021574 -0.042416 -0.021858
# 2023-04-07  0.043339  0.000000  0.063246 -0.011180 -0.009396 -0.002793
# 2023-04-10  0.010769  0.027586  0.017957  0.008794  0.014905  0.050420
# 2023-04-11  0.003044  0.023490  0.012128  0.011208  0.024032  0.074667
# 2023-04-12  0.001517 -0.032787 -0.016340 -0.014778 -0.003911 -0.038462
# 2023-04-13  0.001515  0.015254 -0.017719  0.018750  0.006545  0.034839
# 2023-04-14 -0.015129 -0.008347  0.006764  0.002454 -0.009103  0.000000
# 2023-04-17  0.003072 -0.005051 -0.008959 -0.006120 -0.009186  0.003741
# 2023-04-18  0.004594  0.001692 -0.010169 -0.023399  0.014570  0.024845
# ...

# %% [markdown]
# # 4. 누적 수익률 차트

# %%
ret_df.fillna(method='bfill', inplace=True)

# %%
# plt.figure(figsize=(20,10))
# plt.plot(ret_df.cumsum() , label=ret_df.columns.values)
# plt.legend()
# plt.show()

# %%
((1+ret_df).cumprod()-1).plot(figsize=(20,8))
plt.show()
